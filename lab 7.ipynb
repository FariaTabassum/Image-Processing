# %% [markdown]
# # Smoothing filtering

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from skimage.util import random_noise
from numpy import asarray
from scipy import ndimage

# %%
img = cv2.imread("flower.jpg",0)
data = np.array(img)

# %%
plt.imshow(img)

# %% [markdown]
#  ## Lowpass filtering

# %%
lowkernel = np.array([[1/9,1/9,1/9],
                     [1/9,1/9,1/9],
                     [1/9,1/9,1/9]])
lowpass = cv2.filter2D(src=img,kernel=lowkernel,ddepth=-1)
plt.imshow(lowpass)

# %% [markdown]
# ## Median Filtering

# %%
blur=cv2.blur(img,(5,5))
median=cv2.medianBlur(img,(5))
plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(blur), plt.title('Median Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Max Filtering

# %%
from PIL import Image, ImageFilter
im1=Image.open('flower.jpg')
im2=im1.filter(ImageFilter.MaxFilter(size=3))
max_img=np.hstack((im1,im2))
plt.imshow(max_img)

# %% [markdown]
# ## Min Filtering

# %%
#Min Filtering
im3=im1.filter(ImageFilter.MinFilter(size=3))
min_img=np.hstack((im1,im3))
plt.imshow(min_img)

# %% [markdown]
# ## Midpoint filtering

# %%
#Midpoint Filtering
from numpy import asarray
im2=asarray(im2)
im3=asarray(im3)
midpoint=(im2+im3)*(1/2)
plt.imshow(np.uint8(midpoint))
