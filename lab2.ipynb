# %% [markdown]
# # 1. Convert RGB image to Grayscale image

# %%
#Way 1
from PIL import Image
img = Image.open('flower.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x503 at 0x14951D8AF10>

# %%
img = img.convert('LA')
img
# Out:
# <PIL.Image.Image image mode=LA size=600x503 at 0x14951F0DEE0>

# %%
img.save('greyscale.png')
img
# Out:
# <PIL.Image.Image image mode=LA size=600x503 at 0x14951F0DEE0>

# %%
#way2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

img = mpimg.imread('flower.jpg')

gray = rgb2gray(img)

plt.imshow(gray, cmap = plt.get_cmap('gray'))

plt.savefig('flower_greyscale.png')
plt.show()

# %% [markdown]
# # 2. Convert Grayscale to Binary image

# %%
ret, bw_img = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
plt.imshow(bw_img)

# %% [markdown]
# # 3. Reduce the levels of a grayscale image from 256 to 64, 32 and 16

# %%
#256 to 64
import cv2
X = cv2.imread('flower_greyscale.png') 
Y64 = X / 4;
plt.imshow(Y64)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#256 to 32

Y32 = X / 8;
plt.imshow(Y32)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#256 to 16
Y16 = X / 16;
plt.imshow(Y16)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#way 3
import cv2
img=cv2.imread('flower.jpg')

gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

plt.imshow(gray_img)
